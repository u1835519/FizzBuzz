# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> KARTIK PATIL </b> Student at the University of Warwick

# %% [markdown]
# <i> I am intereseted in Data Science and its applications in Finance and consumer facing data analysis. Furthermore, I am intereseted in learning about neural network and its application in Consumer facing data-analysis projects </i>

# %% [markdown]
# ### My code shows the classic code test of the Fizz Buzz game wherein the output is generally numbers from 1 to 100, however every multiple of 3 is Fizz and every multiple of 5 is Buzz and every multiple of 15 is Fizz Buzz. There are two methods I have used, the first one is slightly longer as it has to have a code to omit 0, while the other one just runs from 1-100. If you know a code wherein I could run a for loop without having to specifically omit 0 and make the code shorter please let me know; your feedback is appreciated

# %%
for var1 in range(101):
    if var1%3==0 and var1%5==0:
        print ("FizzBuzz")
        continue
    elif var1 % 3 == 0:
        print("Fizz")
        continue
    elif var1 % 5 == 0:
        print("Buzz")
        continue
    elif print (var1):
        break
# Out:
# FizzBuzz
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# #####This is the example list with a strikethough, bulleted list and a hyperlink
# <ul>
#     <li> example 1 </li>
#     <li> <a> example 2 </a> </li>
#     <li> <strike> example 3 </strike> </li>
# </ul>

# %%
i=0  
while i<=99:
    i= i+1
    var1 = ""
    if i%5==0 and i%3==0:
        print (var1 + "Fizz Buzz")
        continue
    if i%5==0:
        print (var1 + "Fizz")
        continue
    if i%3==0:
        print (var1 + "Buzz")
    elif print (i):
        break
# Out:
# 1
# 2
# Buzz
# 4
# Fizz
# Buzz
# 7
# 8
# Buzz
# Fizz
# 11
# Buzz
# 13
# 14
# Fizz Buzz
# 16
# 17
# Buzz
# 19
# Fizz
# Buzz
# 22
# 23
# Buzz
# Fizz
# 26
# Buzz
# 28
# 29
# Fizz Buzz
# 31
# 32
# Buzz
# 34
# Fizz
# Buzz
# 37
# 38
# Buzz
# Fizz
# 41
# Buzz
# 43
# 44
# Fizz Buzz
# 46
# 47
# Buzz
# 49
# Fizz
# Buzz
# 52
# 53
# Buzz
# Fizz
# 56
# Buzz
# 58
# 59
# Fizz Buzz
# 61
# 62
# Buzz
# 64
# Fizz
# Buzz
# 67
# 68
# Buzz
# Fizz
# 71
# Buzz
# 73
# 74
# Fizz Buzz
# 76
# 77
# Buzz
# 79
# Fizz
# Buzz
# 82
# 83
# Buzz
# Fizz
# 86
# Buzz
# 88
# 89
# Fizz Buzz
# 91
# 92
# Buzz
# 94
# Fizz
# Buzz
# 97
# 98
# Buzz
# Fizz
